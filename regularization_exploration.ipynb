# %%
import numpy as np
import matplotlib.pyplot as plt
from bezier_utils.core import bezier_curve
from bezier_utils.attributes import osculating_circle_center
from bezier_utils.basic import extract_bezier_curves
from bezier_utils.display import plot_bezier_curves, plot_bezier_curves_by_cross_linear, plot_bezier_curves_by_curvature

# %%
plot_bezier_curves(extract_bezier_curves('data/problems/frag0.svg')[0],extract_bezier_curves('data/problems/frag0.svg')[1], threshold=100.0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plot_bezier_curves(extract_bezier_curves('data/problems/frag0.svg')[0],extract_bezier_curves('data/problems/frag0.svg')[1], threshold=100.0)
#
# File c:\Data\Projects\Adobe_Gensolve\bezier_utils\display.py:213, in plot_bezier_curves(cubic_points, quadratic_points, threshold)
#     211     plt.plot(curve[:, 0], curve[:, 1], label='Cubic Bezier', color=color)
#     212     #plt.plot(points[:, 0], points[:, 1], 'ro--')  # Control points
# --> 213     plt.plot(centers[:, 0], centers[:, 1], 'x', label='Osculating Circle Centers', color=color)  # Osculating circle centers
#     215 for points in quadratic_points:
#     216     curve = bezier_curve(points)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
plot_bezier_curves(extract_bezier_curves('data/problems/frag2.svg')[0],extract_bezier_curves('data/problems/frag2.svg')[1], threshold=10.0)

# %%
print(extract_bezier_curves('data/problems/frag0.svg')[0])
plot_bezier_curves_by_cross_linear(extract_bezier_curves('data/problems/frag0.svg')[0],extract_bezier_curves('data/problems/frag0.svg')[1], threshold=100.0, linear_tolerance=0.0525, show_centers=False)
# Out:
# [[[ 41.942  68.98 ]
#   [ 37.584  74.219]
#   [ 33.91   80.   ]
#   [ 31.114  86.269]]
#
#  [[ 31.114  86.269]
#   [ 23.136 104.156]
#   [ 22.448 128.023]
#   [ 30.39  146.018]]
#
#  [[ 30.39  146.018]
#   [ 32.226 150.179]
#   [ 34.409 154.115]
#   [ 36.891 157.808]]
#
#  [[176.5    67.5  ]
#   [171.555  60.218]
#   [165.893  53.421]
#   [158.893  48.348]]
#
#  [[158.893  48.348]
#   [125.487  24.137]
#   [ 69.766  35.53 ]
#   [ 41.942  68.98 ]]
#
#  [[ 36.891 157.808]
#   [ 64.31  198.601]
#   [128.306 209.766]
#   [166.5   167.5  ]]
#
#  [[ 42.964  70.031]
#   [ 53.818  82.981]
#   [ 72.618  71.863]
#   [ 80.894  95.184]]
#
#  [[ 80.894  95.184]
#   [ 84.384 105.02 ]
#   [ 81.922 122.488]
#   [ 78.675 132.286]]
#
#  [[ 78.675 132.286]
#   [ 70.545 156.818]
#   [ 52.746 144.905]
#   [ 38.041 156.835]]
#
#  [[166.5   167.5  ]
#   [184.026 146.046]
#   [190.851 129.771]
#   [189.97  106.952]]
#
#  [[189.97  106.952]
#   [189.424  92.814]
#   [185.394  80.666]
#   [176.5    67.5  ]]
# ...

# %%
plot_bezier_curves_by_cross_linear(extract_bezier_curves('data/problems/frag2.svg')[0],extract_bezier_curves('data/problems/frag1.svg')[1], threshold=100.0, linear_tolerance=0.027, show_centers=False)

# %%
plot_bezier_curves_by_curvature(extract_bezier_curves('data/problems/frag01.svg')[0],extract_bezier_curves('data/problems/frag0.svg')[1], threshold=100.0, curvature_tolerance=0.01, show_centers=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_bezier_curves_by_curvature(extract_bezier_curves('data/problems/frag01.svg')[0],extract_bezier_curves('data/problems/frag0.svg')[1], threshold=100.0, curvature_tolerance=0.01, show_centers=False)
#
# NameError: name 'plot_bezier_curves_by_curvature' is not defined

# %%
plot_bezier_curves_by_curvature(extract_bezier_curves('data/problems/frag2.svg')[0],extract_bezier_curves('data/problems/frag2.svg')[1], threshold=100.0, curvature_tolerance=0.01, show_centers=False)
